# %% [markdown]
# Tutorial: utilize AML to train and deploy model for image detection task with pytorch tiny yolo v3 neutral network.

# %% [markdown]
# Check the AML core SDK version and config diagnostics functioon

# %%
import azureml.core
print("SDK version:", azureml.core.VERSION)
from azureml.telemetry import set_diagnostics_collection
set_diagnostics_collection(send_diagnostics=True)
# Out:
# Turning diagnostics collection on.

# %% [markdown]
# Get the AML warkspace parameters and print it out

# %%
from azureml.core.workspace import Workspace

ws = Workspace.from_config()
print('Workspace name: ' + ws.name, 
      'Azure region: ' + ws.location, 
      'Subscription id: ' + ws.subscription_id, 
      'Resource group: ' + ws.resource_group, sep='\n')
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# To sign in, use a web browser to open the page https://microsoft.com/devicelogin and enter the code FN9S96DNX to authenticate.
# You have logged in. Now let us find all the subscriptions to which you have access...
# Interactive authentication successfully completed.
# Workspace name: cv_aml
# Azure region: westus2
# Subscription id: 2cb3bb6f-07cb-4778-8927-248b924cfaa7
# Resource group: learnaml

# %% [markdown]
# Prepare training data as dataset

# %%
from azureml.core import Datastore
from azureml.core import Dataset
datastore = Datastore.register_azure_blob_container(workspace = ws, 
                                        datastore_name = 'img_ds',
                                        container_name = 'source-data',
                                        account_name = 'amlpocwestus6466069240',
                                        sas_token = '?sv=2019-12-12&ss=b&srt=co&sp=rlx&se=2021-03-31T15:28:38Z&st=2021-02-02T07:28:38Z&spr=https&sig=3KyJdypHKf%2FxktopuYLAbzy6YszG3LTpMUKHD5Qkn3I%3D',
                                        overwrite=False
                                        )
datastore_paths = [(datastore, 'anji_data')]
dataset = Dataset.File.from_files(path=datastore_paths)
print(datastore)
# Out:
# {
#   "name": "img_ds",
#   "container_name": "source-data",
#   "account_name": "amlpocwestus6466069240",
#   "protocol": "https",
#   "endpoint": "core.windows.net"
# }

# %% [markdown]
# Build Experiment named as exp-yolov3-sample for this training, deployment and inference process.
# Prepare dependencies for yolo v3 pytorch implementation

# %%
from azureml.core import Experiment
experiment_name = 'exp-yolov3-sample'
experiment = Experiment(ws, name=experiment_name)
pytorch_env = Environment.from_conda_specification(name = 'pytorch-1.6-gpu', 
                                                file_path = './conda_dependencies.yml'
                                                )

# %% [markdown]
# Prepare Script parameters for this experiment. The parameters for training can be assigned here as arguments,
# such as -- epoches, --batchsizes,  --cfg and so on. The detailed parameters can be found in train.py file.
# dataset must be mounted here. The path and name of dataset can be assigned differently.

# %%
from azureml.core import ScriptRunConfig

project_folder = '.'

src = ScriptRunConfig(source_directory=project_folder,
                      script='train.py',
                      arguments=['--epochs', 6,'--data-folder', dataset.as_mount('/tmp/tmp_imgdata')],
                      environment=pytorch_env)

# %% [markdown]
# Submit training request and run the training process. The labels and images of training data will be imported.
# The loss and other evaluation criteria will be calculated since the training processes after each epoch.
# The best model will be saved in outputs folder. Print intermediate results.

# %%
run = experiment.submit(src,tags={"purpose":"AML yolov3 sample"})
print(run)
# Out:
# Run(Experiment: exp-yolov3-sample,
# Id: exp-yolov3-sample_1612282990_c4d95690,
# Type: azureml.scriptrun,
# Status: Preparing)

# %%
run.wait_for_completion(show_output=True)
# Out:
# RunId: exp-yolov3-sample_1612282990_c4d95690
# Web View: https://ml.azure.com/experiments/exp-yolov3-sample/runs/exp-yolov3-sample_1612282990_c4d95690?wsid=/subscriptions/2cb3bb6f-07cb-4778-8927-248b924cfaa7/resourcegroups/learnaml/workspaces/cv_aml
#
# Streaming azureml-logs/60_control_log.txt
# =========================================
#
# [2021-02-02T16:23:17.101966] Entering context manager injector.
# [2021-02-02T16:23:17.900605] Using urllib.request Python 3.0 or later
# Streaming log file azureml-logs/60_control_log.txt
# Running: ['/bin/bash', '/tmp/azureml_runs/exp-yolov3-sample_1612282990_c4d95690/azureml-environment-setup/conda_env_checker.sh']
# Starting the daemon thread to refresh tokens in background for process with pid = 5630
# Materialized conda environment not found on target: /home/azureuser/.azureml/envs/azureml_3920396d68489eb8cba06b51559acad7
#
#
# [2021-02-02T16:23:18.006710] Logging experiment preparation status in history service.
# Running: ['/bin/bash', '/tmp/azureml_runs/exp-yolov3-sample_1612282990_c4d95690/azureml-environment-setup/conda_env_builder.sh']
# Running: ['conda', '--version']
# conda 4.9.2
#
# Creating conda environment...
# Running: ['conda', 'env', 'create', '-p', '/home/azureuser/.azureml/envs/azureml_3920396d68489eb8cba06b51559acad7', '-f', 'azureml-environment-setup/mutated_conda_dependencies.yml']
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
# libffi-3.2.1         | 52 KB     | ########## | 100%
# readline-7.0         | 387 KB    | ########## | 100%
# python-3.6.2         | 27.0 MB   | ########## | 100%
# libedit-3.1          | 171 KB    | ########## | 100%
# ncurses-6.0          | 907 KB    | ########## | 100%
# scikit-learn-0.22.1  | 7.1 MB    | ########## | 100%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
#
# [2021-02-02T16:26:43.751617] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError', 'UserExceptions:context_managers.UserExceptions'], invocation=['train.py', '--epochs', '6', '--data-folder', 'DatasetConsumptionConfig:input__3c702d30'])
# Initialize DatasetContextManager.
# Script type = None
# Starting the daemon thread to refresh tokens in background for process with pid = 6589
# Set Dataset input__3c702d30's target path to /tmp/tmp_imgdata
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.21.0.post2 azureml-dataprep==2.8.2. Session id: e2eee618-f3c1-418e-a696-01afb959d26b. Run id: exp-yolov3-sample_1612282990_c4d95690.
# Processing 'input__3c702d30'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('img_ds', 'anji_data')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "63a7715c-bc3a-4c41-ba4e-6712c3741105",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='cv_aml', subscription_id='2cb3bb6f-07cb-4778-8927-248b924cfaa7', resource_group='learnaml')"
#   }
# }
# Mounting input__3c702d30 to /tmp/tmp_imgdata.
# Mounted input__3c702d30 to /tmp/tmp_imgdata as folder.
# Exit __enter__ of DatasetContextManager
# Entering Run History Context Manager.
# [2021-02-02T16:27:02.825851] Current directory: /tmp/azureml_runs/exp-yolov3-sample_1612282990_c4d95690
# [2021-02-02T16:27:02.826018] Preparing to call script [train.py] with arguments:['--epochs', '6', '--data-folder', '$input__3c702d30']
# [2021-02-02T16:27:02.826304] After variable expansion, calling script [train.py] with arguments:['--epochs', '6', '--data-folder', '/tmp/tmp_imgdata']
#
# Apex recommended for faster mixed precision training: https://github.com/NVIDIA/apex
# Namespace(adam=False, batch_size=16, bucket='', cache_images=False, cfg='cfg/yolov3-tiny-3cls.cfg', data='data/detect.data', data_folder='/tmp/tmp_imgdata', device='', epochs=6, evolve=False, img_size=[320, 640], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-tiny.conv.15')
# Data folder: /tmp/tmp_imgdata
# ['ImageSets', 'annotations', 'images', 'labels', 'test.txt', 'train.txt', 'trainval.txt', 'val.shapes', 'val.txt', 'voc_label.py', 'xml2json.py']
# Using CUDA device0 _CudaDeviceProperties(name='Tesla K80', total_memory=11441MB)
#
# Start Tensorboard with "tensorboard --logdir=runs", view at http://localhost:6006/
# data/train.txt
# Model Summary: 37 layers, 8.6745e+06 parameters, 8.6745e+06 gradients
# Optimizer groups: 13 .bias, 13 Conv2d.weight, 11 other
#
# Caching labels:   0%|          | 0/6265 [00:00<?, ?it/s]
# Caching labels (1 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   0%|          | 1/6265 [00:00<1:29:59,  1.16it/s]
# Caching labels (6 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   0%|          | 6/6265 [00:00<13:10,  7.92it/s]
# Caching labels (11 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   0%|          | 11/6265 [00:01<07:19, 14.23it/s]
# Caching labels (27 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   0%|          | 27/6265 [00:01<02:33, 40.65it/s]
# Caching labels (41 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   1%|          | 41/6265 [00:01<01:41, 61.13it/s]
# Caching labels (52 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   1%|          | 52/6265 [00:01<01:29, 69.52it/s]
# Caching labels (68 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   1%|          | 68/6265 [00:01<01:08, 90.88it/s]
# Caching labels (80 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   1%|▏         | 80/6265 [00:01<01:10, 88.25it/s]
# Caching labels (91 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   1%|▏         | 91/6265 [00:01<01:07, 90.97it/s]
# Caching labels (108 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   2%|▏         | 108/6265 [00:01<00:56, 109.90it/s]
# Caching labels (123 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   2%|▏         | 123/6265 [00:01<00:51, 119.58it/s]
# Caching labels (141 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   2%|▏         | 141/6265 [00:02<00:45, 134.22it/s]
# Caching labels (156 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   2%|▏         | 156/6265 [00:02<00:44, 137.78it/s]
# Caching labels (173 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   3%|▎         | 173/6265 [00:02<00:41, 146.27it/s]
# Caching labels (190 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   3%|▎         | 190/6265 [00:02<00:40, 151.10it/s]
# Caching labels (207 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   3%|▎         | 207/6265 [00:02<00:38, 155.62it/s]
# Caching labels (223 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   4%|▎         | 223/6265 [00:02<00:40, 148.35it/s]
# Caching labels (240 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   4%|▍         | 240/6265 [00:02<00:39, 150.94it/s]
# Caching labels (256 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   4%|▍         | 256/6265 [00:02<00:39, 150.64it/s]
# Caching labels (274 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   4%|▍         | 274/6265 [00:02<00:38, 156.37it/s]
# Caching labels (290 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   5%|▍         | 290/6265 [00:03<01:00, 98.98it/s]
# Caching labels (304 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   5%|▍         | 304/6265 [00:03<00:56, 106.33it/s]
# Caching labels (322 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   5%|▌         | 322/6265 [00:03<00:49, 121.17it/s]
# Caching labels (337 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   5%|▌         | 337/6265 [00:03<00:47, 123.70it/s]
# Caching labels (352 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   6%|▌         | 352/6265 [00:03<00:45, 129.78it/s]
# Caching labels (367 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   6%|▌         | 367/6265 [00:03<00:46, 128.14it/s]
# Caching labels (382 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   6%|▌         | 382/6265 [00:03<00:44, 132.92it/s]
# Caching labels (398 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   6%|▋         | 398/6265 [00:04<00:42, 138.55it/s]
# Caching labels (413 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   7%|▋         | 413/6265 [00:04<00:42, 137.47it/s]
# Caching labels (428 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   7%|▋         | 428/6265 [00:04<00:42, 138.90it/s]
# Caching labels (445 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   7%|▋         | 445/6265 [00:04<00:39, 146.10it/s]
# Caching labels (460 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   7%|▋         | 460/6265 [00:04<00:45, 127.43it/s]
# Caching labels (476 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   8%|▊         | 476/6265 [00:04<00:42, 134.72it/s]
# Caching labels (490 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   8%|▊         | 490/6265 [00:04<00:50, 114.36it/s]
# Caching labels (507 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   8%|▊         | 507/6265 [00:04<00:45, 127.69it/s]
# Caching labels (521 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   8%|▊         | 521/6265 [00:04<00:44, 128.44it/s]
# Caching labels (537 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   9%|▊         | 537/6265 [00:05<00:42, 135.29it/s]
# Caching labels (554 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   9%|▉         | 554/6265 [00:05<00:39, 144.21it/s]
# Caching labels (569 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   9%|▉         | 569/6265 [00:05<00:40, 141.46it/s]
# Caching labels (584 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):   9%|▉         | 584/6265 [00:05<00:44, 129.02it/s]
# Caching labels (599 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):  10%|▉         | 599/6265 [00:05<00:42, 134.29it/s]
# Caching labels (616 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):  10%|▉         | 616/6265 [00:05<00:39, 143.16it/s]
# Caching labels (633 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):  10%|█         | 633/6265 [00:05<00:37, 150.55it/s]
# Caching labels (649 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):  10%|█         | 649/6265 [00:05<00:39, 142.21it/s]
# Caching labels (665 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):  11%|█         | 665/6265 [00:05<00:38, 145.83it/s]
# Caching labels (682 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):  11%|█         | 682/6265 [00:06<00:37, 150.53it/s]
# Caching labels (698 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):  11%|█         | 698/6265 [00:06<00:44, 124.87it/s]
# Caching labels (715 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):  11%|█▏        | 715/6265 [00:06<00:41, 134.82it/s]
# Caching labels (731 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):  12%|█▏        | 731/6265 [00:06<00:39, 139.04it/s]
# Caching labels (746 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):  12%|█▏        | 746/6265 [00:06<00:43, 125.85it/s]
# Caching labels (760 found, 0 missing, 0 empty, 0 duplicate, for 6265 images):
#        0/5     6.05G      4.77      2.14      1.37      8.28       117       640:  37%|███▋      | 144/392 [01:18<02:13,  1.86it/s]
#        0/5     6.05G      4.77      2.14      1.37      8.28       117       640:  37%|███▋      | 145/392 [01:18<02:25,  1.70it/s]
#        0/5     6.05G      4.77      2.13      1.37      8.26        80       640:  37%|███▋      | 145/392 [01:18<02:25,  1.70it/s]
#        0/5     6.05G      4.77      2.13      1.37      8.26        80       640:  37%|███▋      | 146/392 [01:18<02:34,  1.59it/s]

# %% [markdown]
# Comfirm the training experiment is finished.

# %%
assert(run.get_status() == "Completed")
print(run.get_file_names())

# %% [markdown]
# Register the best Model

# %%
 model = run.register_model(model_name = 'yolov3-sample-model', model_path = 'outputs/best.pt')
print(model.name, model.id, model.version, sep = '\t')

# %% [markdown]
# Deploy the Model with ACI Webservice method

# %%
# 
from azureml.core import Environment
from azureml.core.webservice import AciWebservice
from azureml.core.model import InferenceConfig
from azureml.core.webservice import Webservice
from azureml.core.model import Model

#model = Model(ws, 'yolov3-sample-model')

pytorch_env = Environment.from_conda_specification(name = 'pytorch-1.6-gpu', file_path = './conda_dependencies.yml')
dockerfile = """
FROM mcr.microsoft.com/azureml/openmpi3.1.2-cuda10.1-cudnn7-ubuntu18.04
RUN apt update
RUN apt-get -y install sudo
RUN sudo apt -y install libgl1-mesa-glx
"""
pytorch_env.docker.enabled = True
pytorch_env.docker.base_image = None
pytorch_env.docker.base_dockerfile = dockerfile
pytorch_env.inferencing_stack_version = 'latest'

inference_config = InferenceConfig(
        entry_script="score.py", 
        environment=pytorch_env,
        source_directory = "./"
        )

aciconfig = AciWebservice.deploy_configuration(cpu_cores=2, 
                                               memory_gb=2, 
                                               tags={'framework':'pytorch'},
                                               description='ACI with Yolov3')

service = Model.deploy(workspace=ws, 
                           name='aci-yolov3-sample', 
                           models=[model], 
                           inference_config=inference_config, 
                           deployment_config=aciconfig)
service.wait_for_deployment(True)
print(service.state)

# %%
service.get_logs()
print(service.scoring_uri)

# %% [markdown]
# Use the deployed model to do inference process: input an image and use the deployed model to detect objects.

# %%
import json
from PIL import Image
import matplotlib.pyplot as plt

# %matplotlib inline
plt.imshow(Image.open('testfiles/test-image-2.jpg'))

# %%
import requests
from base64 import b64encode
# send a random row from the test set to score
with open('testfiles/test-image-2.jpg', 'rb') as jpg_file:
    byte_content = jpg_file.read()
    jpg_file.close()
base64_bytes = b64encode(byte_content)
base64_string = base64_bytes.decode()

input_data=json.dumps({'data': base64_string})

headers = {'Content-Type':'application/json'}

resp = requests.post(service.scoring_uri, input_data, headers=headers)

max_len = len(resp.text) -1
result = resp.text[1:max_len].replace("\\","")

# %%
import base64

result_image = json.loads(result)["result_image"]

image_data = base64.b64decode(result_image)

with open('testfiles/test-impage-2-detection.jpg', 'wb') as jpg_file:
    jpg_file.write(image_data)

# %matplotlib inline
plt.imshow(Image.open('testfiles/test-impage-2-detection.jpg'))

# %% [markdown]
# Delete ACI and datastore

# %%
service.delete()
datastore.unregister()
